# %%
import tensorflow as tf
from tensorflow.keras import datasets, layers, models
import matplotlib.pyplot as plt

# %% [markdown]
# Load CIFAR-10 Dataset

# %%
(x_train, y_train), (x_test, y_test) = datasets.cifar10.load_data()
# Out:
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz
# 170498071/170498071 ━━━━━━━━━━━━━━━━━━━━ 2s 0us/step

# %% [markdown]
# Normalize the data

# %%
x_train = x_train / 255.0
x_test = x_test / 255.0

# %% [markdown]
# Build Simple CNN Model

# %%
model = models.Sequential()

# %% [markdown]
# First Convolution Layer

# %%
model.add(layers.Conv2D(32, (3,3), activation='relu', input_shape=(32,32,3)))
model.add(layers.MaxPooling2D((2,2)))
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/convolutional/base_conv.py:113: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %% [markdown]
# Second Convolution Layer

# %%
model.add(layers.Conv2D(64, (3,3), activation='relu'))
model.add(layers.MaxPooling2D((2,2)))

# %% [markdown]
# Third Convolution Layer

# %%
model.add(layers.Conv2D(64, (3,3), activation='relu'))

# %% [markdown]
# Flatten Layer

# %%
model.add(layers.Flatten())

# %% [markdown]
# Fully Connected Layer

# %%
model.add(layers.Dense(64, activation='relu'))

# %% [markdown]
# Output Layer (10 classes)

# %%
model.add(layers.Dense(10, activation='softmax'))

# %% [markdown]
# Compile Model

# %%
model.compile(optimizer='adam',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

# %% [markdown]
# Train Model

# %%
history = model.fit(x_train, y_train, epochs=10,
                    validation_data=(x_test, y_test))
# Out:
# Epoch 1/10
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 69s 43ms/step - accuracy: 0.3507 - loss: 1.7526 - val_accuracy: 0.5505 - val_loss: 1.2349
# Epoch 2/10
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 80s 42ms/step - accuracy: 0.5769 - loss: 1.2010 - val_accuracy: 0.5893 - val_loss: 1.1609
# Epoch 3/10
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 68s 44ms/step - accuracy: 0.6416 - loss: 1.0287 - val_accuracy: 0.6560 - val_loss: 0.9945
# Epoch 4/10
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 66s 42ms/step - accuracy: 0.6799 - loss: 0.9095 - val_accuracy: 0.6865 - val_loss: 0.9164
# Epoch 5/10
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 66s 42ms/step - accuracy: 0.7042 - loss: 0.8380 - val_accuracy: 0.6823 - val_loss: 0.9055
# Epoch 6/10
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 82s 43ms/step - accuracy: 0.7295 - loss: 0.7674 - val_accuracy: 0.6917 - val_loss: 0.8888
# Epoch 7/10
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 66s 42ms/step - accuracy: 0.7468 - loss: 0.7199 - val_accuracy: 0.7094 - val_loss: 0.8573
# Epoch 8/10
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 81s 42ms/step - accuracy: 0.7625 - loss: 0.6766 - val_accuracy: 0.6988 - val_loss: 0.8934
# Epoch 9/10
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 67s 43ms/step - accuracy: 0.7780 - loss: 0.6281 - val_accuracy: 0.6779 - val_loss: 0.9802
# Epoch 10/10
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 83s 43ms/step - accuracy: 0.7925 - loss: 0.5886 - val_accuracy: 0.7167 - val_loss: 0.8492

# %% [markdown]
# Evaluate Model

# %%
test_loss, test_acc = model.evaluate(x_test, y_test)
print("Test Accuracy:", test_acc)
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - accuracy: 0.7145 - loss: 0.8462
# Test Accuracy: 0.71670001745224
